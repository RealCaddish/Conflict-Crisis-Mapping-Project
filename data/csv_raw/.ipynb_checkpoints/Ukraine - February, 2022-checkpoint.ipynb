# %%
## this notebook will be used to explore and format data from the ACLED for Ukraine in February of 2022.

# %%
import pandas as pd
import geopandas as gpd 
import matplotlib.pyplot as plt

# %%
# import ACLED data from file
data = gpd.read_file('../csv_raw/February_2022.csv')

# %%
# what are the datatypes, column values, and memory usage?
data.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 29539 entries, 0 to 29538
# Data columns (total 32 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   data_id           29539 non-null  object
#  1   iso               29539 non-null  object
#  2   event_id_cnty     29539 non-null  object
#  3   event_id_no_cnty  29539 non-null  object
#  4   event_date        29539 non-null  object
#  5   year              29539 non-null  object
#  6   time_precision    29539 non-null  object
#  7   event_type        29539 non-null  object
#  8   sub_event_type    29539 non-null  object
#  9   actor1            29539 non-null  object
#  10  assoc_actor_1     29539 non-null  object
#  11  inter1            29539 non-null  object
#  12  actor2            29539 non-null  object
#  13  assoc_actor_2     29539 non-null  object
#  14  inter2            29539 non-null  object
#  15  interaction       29539 non-null  object
# ...

# %%
# explore rows and columns
data.head()
# Out:
#    data_id  iso event_id_cnty event_id_no_cnty        event_date  year  \
# 0  8853470  804      UKR51376            51376  18 February 2022  2022
# 1  8853472  804      UKR51403            51403  18 February 2022  2022
# 2  8853473  804      UKR51408            51408  18 February 2022  2022
# 3  8853474  804      UKR51410            51410  18 February 2022  2022
# 4  8853475  804      UKR51413            51413  18 February 2022  2022
#
#   time_precision                  event_type  \
# 0              1                     Battles
# 1              1  Explosions/Remote violence
# 2              1  Explosions/Remote violence
# 3              1  Explosions/Remote violence
# 4              1  Explosions/Remote violence
#
#                       sub_event_type                              actor1  ...  \
# 0                        Armed clash  Military Forces of Ukraine (2019-)  ...
# 1  Shelling/artillery/missile attack  Military Forces of Ukraine (2019-)  ...
# ...

# %%
# create geodataframe object from lat, long points
gdf = gpd.GeoDataFrame(data, geometry=gpd.points_from_xy(data.longitude, data.latitude))

# %%
gdf.plot()
# Out:
# <AxesSubplot:>

# %%
gdf.event_date
# Out:
# 0        18 February 2022
# 1        18 February 2022
# 2        18 February 2022
# 3        18 February 2022
# 4        18 February 2022
#                ...
# 29534    19 February 2019
# 29535    19 February 2019
# 29536    19 February 2019
# 29537    19 February 2019
# 29538    19 February 2019
# Name: event_date, Length: 29539, dtype: object

# %%
# check to make sure the geometry column is properly described
gdf.head()
# Out:
#    data_id  iso event_id_cnty event_id_no_cnty        event_date  year  \
# 0  8853470  804      UKR51376            51376  18 February 2022  2022
# 1  8853472  804      UKR51403            51403  18 February 2022  2022
# 2  8853473  804      UKR51408            51408  18 February 2022  2022
# 3  8853474  804      UKR51410            51410  18 February 2022  2022
# 4  8853475  804      UKR51413            51413  18 February 2022  2022
#
#   time_precision                  event_type  \
# 0              1                     Battles
# 1              1  Explosions/Remote violence
# 2              1  Explosions/Remote violence
# 3              1  Explosions/Remote violence
# 4              1  Explosions/Remote violence
#
#                       sub_event_type                              actor1  ...  \
# 0                        Armed clash  Military Forces of Ukraine (2019-)  ...
# 1  Shelling/artillery/missile attack  Military Forces of Ukraine (2019-)  ...
# ...

# %%
gdf_february = gdf.loc[gdf.event_date=="18 February 2022"]

# %%
gdf_february.head()
# Out:
#    data_id  iso event_id_cnty event_id_no_cnty        event_date  year  \
# 0  8853470  804      UKR51376            51376  18 February 2022  2022
# 1  8853472  804      UKR51403            51403  18 February 2022  2022
# 2  8853473  804      UKR51408            51408  18 February 2022  2022
# 3  8853474  804      UKR51410            51410  18 February 2022  2022
# 4  8853475  804      UKR51413            51413  18 February 2022  2022
#
#   time_precision                  event_type  \
# 0              1                     Battles
# 1              1  Explosions/Remote violence
# 2              1  Explosions/Remote violence
# 3              1  Explosions/Remote violence
# 4              1  Explosions/Remote violence
#
#                       sub_event_type                              actor1  ...  \
# 0                        Armed clash  Military Forces of Ukraine (2019-)  ...
# 1  Shelling/artillery/missile attack  Military Forces of Ukraine (2019-)  ...
# ...
